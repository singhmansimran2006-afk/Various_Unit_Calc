# %%
print("Hello VGU");
# Out:
# Hello VGU

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b = "hello vgu"

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
c = 3.14

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
d = True

# %%
print(type(d))
# Out:
# <class 'bool'>

# %%
z = int(c)

# %%
print(type(z))
# Out:
# <class 'int'>

# %%
name = input ("Enter your Name :")
# Out:
# Enter your Name : Mansimran

# %%
print(name)
# Out:
# Mansimran

# %%
e = "Hello"

# %%
print(type(e))
# Out:
# <class 'str'>

# %%
# this is a comment

# %%
""" sjkebfbsbjsenfjef """
# Out:
# ' sjkebfbsbjsenfjef '

# %% [markdown]
# Operators in python

# %%
a = 3
b = 2

# %%
c = a + b

# %%
print(c)
# Out:
# 3

# %%
print (b - a)
# Out:
# 1

# %%
print (a ** b)
# Out:
# 9

# %%
print (a * b)
# Out:
# 6

# %% [markdown]
# Comparision Operator

# %%
a = 10
b = 5

# %%
print(a > b)
# Out:
# True

# %%
print (a < b)
# Out:
# False

# %%
print (a ==b)
# Out:
# False

# %%
print (a != b)
# Out:
# True

# %% [markdown]
# Logical Operator

# %%
age = 18

# %%
print ( age > 16 and age < 20 )
# Out:
# True

# %%
print ( age > 19 and age < 20 )
# Out:
# False

# %% [markdown]
# Assignment Operator

# %%
x= 10

# %%
x += 2 # x = x + 2

# %%
print(x)
# Out:
# 12

# %% [markdown]
# Identity Operator

# %%
a = 1

# %%
b = a

# %%
print ( a is b )
# Out:
# True

# %% [markdown]
# Project 1

# %%
num1 = float(input ("Enter your first number : "))
num2 = float(input ("Enter your second number : "))
# Out:
# Enter your first number :  2
# Enter your second number :  3

# %%
print (f'First number is :' , num1, 'and second number is :', num2)
# Out:
# First number is : 2.0 and second number is : 3.0

# %%
print ("Addition is :", num1 + num2)
print ("Substraction is :", num1 - num2)
print ("Multiplication is :", num1 * num2)
# Out:
# Addition is : 5.0
# Substraction is : -1.0
# Multiplication is : 6.0

# %% [markdown]
# Celcius to Fahrenheit

# %%
C = float(input("Enter the Temperature"))
F = float ((C * 1.8) + 32)         

print ("Your Temperature in F is :", F)
# Out:
# Enter the Temperature 40
# Your Temperature in F is : 104.0

# %% [markdown]
# Celcius to Kelvin

# %%
C = float(input("Enter your Temperature"))
K = float( C + 273.15 )
print ("Your Temperature in K is :", K)
# Out:
# Enter your Temperature 36
# Your Temperature in K is : 309.15

# %% [markdown]
# MilliMetres to Inches

# %%
mm = float(input("Enter your value"))
In = float( mm/25.4 )
print("Your value in Inches is : ", In )
# Out:
# Enter your value 2598
# Your value in Inches is :  102.28346456692914

# %% [markdown]
# Kilometres to Metres

# %%
km = float(input("Enter your distance"))
m = float( km * 1000 )
print ("Your distance in m is : ", m)
# Out:
# Enter your distance 5
# Your distance in m is :  5000.0

# %% [markdown]
# Days to Seconds

# %%
days = float(input("Enter your value in days"))
sec = float(days * 86400)
print ("Your value in seconds is : ", sec)
# Out:
# Enter your value in days 2
# Your value in seconds is :  172800.0

# %% [markdown]
# Inches to Kilometre

# %%
i = float(input("Enter your value"))
km = float( i / 39370)
print("Your value in km is :", km)
# Out:
# Enter your value 2
# Your value in km is : 5.08001016002032e-05
